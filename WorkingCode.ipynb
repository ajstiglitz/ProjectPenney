# %% [markdown]
# ### The code below is to show how to set up the decks and subsequently calculate the probabilities.

# %% [markdown]
# #### Imports for Set-Up

# %%
import importlib
import src.datagen
import src.processing
import src.computing
import src.visualization

importlib.reload(src.datagen)
importlib.reload(src.processing)
importlib.reload(src.computing)
importlib.reload(src.visualization)
# Out:
# <module 'src.visualization' from 'C:\\Users\\ajs09\\Downloads\\DATA440\\projects\\ProjectPenney\\src\\visualization.py'>

# %% [markdown]
# #### Arbitrary n and seed that can be changed.
# - set for reproducibility

# %%
deck = src.datagen.get_decks(100,55)

# %%
#as you can see from the output, it tells you that I ran this three times
#twice with n=100 and seed=31
src.datagen.store_decks(100,55,deck)
# Out:
# {'seed55_decks100_timestamp2025-03-01-21-22-47-508625.npy': {'seed': 55,
#   'n': 100},
#  'seed55_decks100_timestamp2025-03-01-21-23-15-052350.npy': {'seed': 55,
#   'n': 100}}

# %%
src.processing.update_score()
# Out:
# Loading data\to_load\seed55_decks100_timestamp2025-03-01-21-23-15-052350.npy
# File: data\to_load\seed55_decks100_timestamp2025-03-01-21-23-15-052350.npy moved to: data\loaded

# %%
matrix = src.computing.calc_probability()

# %%
src.visualization.decks_heatmap(matrix, 100)
# Out:
# <Axes: title={'center': 'Probability of Player 1 Winning When n_decks = 100'}>
