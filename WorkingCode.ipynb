# %% [markdown]
# ### The code below is to show how to set up the decks and subsequently calculate the probabilities.

# %% [markdown]
# #### Imports for Set-Up

# %%
import importlib
import src.datagen
import src.processing
import src.computing
import src.visualization

importlib.reload(src.datagen)
importlib.reload(src.processing)
importlib.reload(src.computing)
importlib.reload(src.visualization)
# Out:
# <module 'src.visualization' from 'C:\\Users\\ajs09\\Downloads\\DATA440\\projects\\ProjectPenney\\src\\visualization.py'>

# %% [markdown]
# #### Arbitrary n and seed that can be changed.
# - set for reproducibility

# %%
# creating a deck variable that has the number of random decks generated with a random seed
deck = src.datagen.get_decks(100000,42)

# %%
# codes to store the decks. It needs n_decks, a random seed, and the deck variable from the above cell
src.datagen.store_decks(100000,42,deck)
# Out:
# {'seed42_decks100000_split10_timestamp2025-03-28-19-52-21-822297.npy': {'seed': 42,
#   'n': 100000}}

# %%
# code to score the decks and update their location
src.processing.update_score()
# Out:
# Loading data\to_load\seed42_decks100000_split10_timestamp2025-03-28-19-14-08-229289.npy
# File: data\to_load\seed42_decks100000_split10_timestamp2025-03-28-19-14-08-229289.npy moved to: data\loaded
# Loading data\to_load\seed42_decks100000_split1_timestamp2025-03-28-19-14-08-229289.npy
# File: data\to_load\seed42_decks100000_split1_timestamp2025-03-28-19-14-08-229289.npy moved to: data\loaded
# Loading data\to_load\seed42_decks100000_split2_timestamp2025-03-28-19-14-08-229289.npy
# File: data\to_load\seed42_decks100000_split2_timestamp2025-03-28-19-14-08-229289.npy moved to: data\loaded
# Loading data\to_load\seed42_decks100000_split3_timestamp2025-03-28-19-14-08-229289.npy
# File: data\to_load\seed42_decks100000_split3_timestamp2025-03-28-19-14-08-229289.npy moved to: data\loaded
# Loading data\to_load\seed42_decks100000_split4_timestamp2025-03-28-19-14-08-229289.npy
# File: data\to_load\seed42_decks100000_split4_timestamp2025-03-28-19-14-08-229289.npy moved to: data\loaded
# Loading data\to_load\seed42_decks100000_split5_timestamp2025-03-28-19-14-08-229289.npy
# File: data\to_load\seed42_decks100000_split5_timestamp2025-03-28-19-14-08-229289.npy moved to: data\loaded
# Loading data\to_load\seed42_decks100000_split6_timestamp2025-03-28-19-14-08-229289.npy
# File: data\to_load\seed42_decks100000_split6_timestamp2025-03-28-19-14-08-229289.npy moved to: data\loaded
# Loading data\to_load\seed42_decks100000_split7_timestamp2025-03-28-19-14-08-229289.npy
# File: data\to_load\seed42_decks100000_split7_timestamp2025-03-28-19-14-08-229289.npy moved to: data\loaded
# Loading data\to_load\seed42_decks100000_split8_timestamp2025-03-28-19-14-08-229289.npy
# File: data\to_load\seed42_decks100000_split8_timestamp2025-03-28-19-14-08-229289.npy moved to: data\loaded
# Loading data\to_load\seed42_decks100000_split9_timestamp2025-03-28-19-14-08-229289.npy
# File: data\to_load\seed42_decks100000_split9_timestamp2025-03-28-19-14-08-229289.npy moved to: data\loaded

# %%
# variable created for the calculated probability
matrix = src.computing.calc_probability()

# %%
# code for the heatmap visualization
src.visualization.decks_heatmap(matrix, 100000)
# Out:
# <Axes: title={'center': 'My Chance of Win(Draw) by ___ When n_decks = 100000'}>
