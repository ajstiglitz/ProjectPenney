# %% [markdown]
# ### The code below is to show how to set up the decks and subsequently calculate the probabilities.

# %% [markdown]
# #### Imports for Set-Up

# %%
import importlib
import src.datagen
import src.processing
import src.computing
import src.visualization

importlib.reload(src.datagen)
importlib.reload(src.processing)
importlib.reload(src.computing)
importlib.reload(src.visualization)
# Out:
# <module 'src.visualization' from 'C:\\Users\\ajs09\\Downloads\\DATA440\\projects\\ProjectPenney\\src\\visualization.py'>

# %% [markdown]
# #### Arbitrary n and seed that can be changed.
# - set for reproducibility

# %%
deck = src.datagen.get_decks(10000,31)

# %%
#as you can see from the output, it tells you that I ran this three times
#twice with n=100 and seed=31
src.datagen.store_decks(10000,31,deck)
# Out:
# {'seed31_decks10000_timestamp2025-02-28-03-21-06-688616.npy': {'seed': 31,
#   'n': 10000},
#  'seed31_decks10000_timestamp2025-02-28-03-21-08-656819.npy': {'seed': 31,
#   'n': 10000},
#  'seed31_decks10000_timestamp2025-02-28-03-21-09-618933.npy': {'seed': 31,
#   'n': 10000},
#  'seed31_decks10000_timestamp2025-02-28-03-21-10-395043.npy': {'seed': 31,
#   'n': 10000},
#  'seed31_decks10000_timestamp2025-02-28-03-21-11-208108.npy': {'seed': 31,
#   'n': 10000},
#  'seed31_decks10000_timestamp2025-02-28-03-21-18-459232.npy': {'seed': 31,
#   'n': 10000}}

# %%
src.processing.update_score()
# Out:
# Loading data\to_load\seed31_decks10000_timestamp2025-02-28-03-21-06-688616.npy
# File: data\to_load\seed31_decks10000_timestamp2025-02-28-03-21-06-688616.npy moved to: data\loaded
# Loading data\to_load\seed31_decks10000_timestamp2025-02-28-03-21-08-656819.npy
# File: data\to_load\seed31_decks10000_timestamp2025-02-28-03-21-08-656819.npy moved to: data\loaded
# Loading data\to_load\seed31_decks10000_timestamp2025-02-28-03-21-09-618933.npy
# File: data\to_load\seed31_decks10000_timestamp2025-02-28-03-21-09-618933.npy moved to: data\loaded
# Loading data\to_load\seed31_decks10000_timestamp2025-02-28-03-21-10-395043.npy
# File: data\to_load\seed31_decks10000_timestamp2025-02-28-03-21-10-395043.npy moved to: data\loaded
# Loading data\to_load\seed31_decks10000_timestamp2025-02-28-03-21-11-208108.npy
# File: data\to_load\seed31_decks10000_timestamp2025-02-28-03-21-11-208108.npy moved to: data\loaded
# Loading data\to_load\seed31_decks10000_timestamp2025-02-28-03-21-18-459232.npy
# File: data\to_load\seed31_decks10000_timestamp2025-02-28-03-21-18-459232.npy moved to: data\loaded

# %%
src.computing.calc_probability()
# Out:
# array([[0.    , 0.3653, 0.0066, 0.1016, 0.6543, 0.3623, 0.3785, 0.5406],
#        [0.711 , 0.    , 0.541 , 0.1717, 0.1686, 0.5795, 0.5519, 0.6816],
#        [0.9961, 0.535 , 0.    , 0.0747, 0.998 , 0.5142, 0.4587, 0.6914],
#        [0.917 , 0.8644, 0.9466, 0.    , 0.5232, 0.0218, 0.8668, 0.4289],
#        [0.4329, 0.8738, 0.0239, 0.523 , 0.    , 0.9464, 0.8737, 0.9159],
#        [0.6932, 0.46  , 0.5221, 0.9967, 0.0776, 0.    , 0.5343, 0.9947],
#        [0.6765, 0.5446, 0.5783, 0.1775, 0.1668, 0.5437, 0.    , 0.7076],
#        [0.5429, 0.3827, 0.3584, 0.6574, 0.1052, 0.0057, 0.3669, 0.    ]])

# %%
src.visualization.decks_heatmap()
# Out:
# <Axes: >
